# %% [markdown]
# Dado el sistema de crecimiento exponencial definido por

# %% [markdown]
# \begin{equation}
# x_t = a x_{t-1}
# \end{equation}

# %% [markdown]
# Realice simulaciones en Octave/Matlab o Python generando series temporales para distintos valores del parametro a y con condicion inicial

# %% [markdown]
# \begin{equation}
# x_0 = 1
# \end{equation}

# %% [markdown]
# Describa el comportamiento y como influye el valor del parametro en el resultado.

# %% [markdown]
# #### Hago la simulacion

# %%
def generate_simulation_sample(a):
    x0 = 1

    x = [x0]

    for i in range(100):
        valor = x[i]
        x.append(a * valor)

    return x

# %%
x = generate_simulation_sample(1.01)
"{}...".format(x[0:5])
# Out:
# '[1, 1.01, 1.0201, 1.030301, 1.04060401]...'

# %% [markdown]
# #### Ploteo la simulacion

# %%
import matplotlib.pyplot as plt
plt.plot(x)
plt.show()

# %% [markdown]
# #### Hacemos varios ejemplos para ver el papel que juega el "a"

# %%
x_1 = generate_simulation_sample(1.01)
x_2 = generate_simulation_sample(1.00)
x_3 = generate_simulation_sample(0.99)

# %%
plt.plot(x_1)
plt.plot(x_2)
plt.plot(x_3)
plt.show()

# %% [markdown]
# #### Finalmente el ultimo "a" interesante es uno negativo

# %%
x_4 = generate_simulation_sample(-1.1)
plt.plot(x_4)
plt.show()

# %%
x_4 = generate_simulation_sample(-0.9)
plt.plot(x_4)
plt.show()
