# %% [markdown]
# Dado el sistema de dos variables definido por:

# %% [markdown]
# $$ x_t = a x_{t-1} + b y_{t-1} $$

# %% [markdown]
# $$ y_t = c x_{t-1} + d y_{t-1} $$

# %% [markdown]
# Realice distintas simulaciones en Octave/Matlab o Python generando series temporales para distintos valores de los parametros a, b, c, d y con condicion inicial

# %% [markdown]
# $$ (x_0, y_0) = (1,1) $$

# %% [markdown]
# Muestre los resultados en forma de trayectorias en el espacio de fases (x, y). Describa los distintos comportamientos que pueden ser obtenidos y justifique teoricamente.

# %% [markdown]
# <hr>

# %% [markdown]
# #### Generador de la simulacion

# %%
def generate_simulation_sample(a, b, c, d):

    x0 = 1
    y0 = 1
    
    pairs = [(x0, y0)]
    
    for i in range(100):
        x_, y_ = pairs[i]
    
        x = a * x_ + b * y_
        y = c * x_ + d * y_

        pairs.append((x, y))
    
    return pairs

# %% [markdown]
# #### Primera prueba

# %%
a = -0.5
b = 0.15
c = -3
d = -0.8
pairs = generate_simulation_sample(a, b, c, d)

# %%
import matplotlib.pyplot as pyplot
pyplot.plot([pair[0] for pair in pairs], [pair[1] for pair in pairs])
pyplot.show()

# %% [markdown]
# #### Segunda prueba

# %%
a = -0.5
b = 0.1
c = -3
d = -0.8
pairs = generate_simulation_sample(a, b, c, d)

# %%
import matplotlib.pyplot as pyplot
pyplot.plot([pair[0] for pair in pairs], [pair[1] for pair in pairs])
pyplot.show()

# %% [markdown]
# #### Tercera prueba

# %%
a = -0.5
b = 0.18
c = -3
d = -0.8
pairs = generate_simulation_sample(a, b, c, d)

# %%
import matplotlib.pyplot as pyplot
pyplot.plot([pair[0] for pair in pairs], [pair[1] for pair in pairs])
pyplot.show()

# %% [markdown]
# #### Cuarta prueba

# %%
a = -0.5
b = 0.2
c = -3
d = -0.8
pairs = generate_simulation_sample(a, b, c, d)

# %%
import matplotlib.pyplot as pyplot
pyplot.plot([pair[0] for pair in pairs], [pair[1] for pair in pairs])
pyplot.show()

# %% [markdown]
# #### Quinta prueba

# %%
a = -0.5
b = 0.18
c = -5
d = -0.5
pairs = generate_simulation_sample(a, b, c, d)

# %%
import matplotlib.pyplot as pyplot
pyplot.plot([pair[0] for pair in pairs], [pair[1] for pair in pairs])
pyplot.show()
