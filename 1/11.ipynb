# %%
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Generacion de un numero random:

# %%
random.random()
# Out:
# 0.1023094505536527

# %% [markdown]
# #### Genero 10 numeros

# %%
generados_x = []
generados_y = []
for i in range(1000):
    generados_x.append(random.random())
    generados_y.append(random.random())

# %% [markdown]
# generados_x

# %% [markdown]
# #### Grafico los resultados

# %%
plt.scatter(generados_x, generados_y, c ="blue")
