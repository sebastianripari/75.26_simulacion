# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# #### Funcion densidad

# %%
def f_x(x):
    return 1-x

# %% [markdown]
# #### Grafico funcion densidad

# %%
values_x = []
values_y = []
for i in range(1000):
    x = random.random()
    y = f_x(x)
    values_x.append(x)
    values_y.append(y)
plt.scatter(values_x, values_y, c ="blue")

# %% [markdown]
# #### Buscamos funcion que mayorice la f

# %%
def t(x):
    return 1

# %%
values_x = []
values_y_1 = []
values_y_2 = []
for i in range(1000):
    x = random.random()
    y_1 = t(x)
    y_2 = f_x(x)
    values_x.append(x)
    values_y_1.append(y_1)
    values_y_2.append(y_2)
plt.scatter(values_x, values_y_1, c ="blue")
plt.scatter(values_x, values_y_2, c ="blue")

# %%
generados = []
for i in range(1000):
    # las variables u_r, x son lo mismo porque
    # la inversa de x queda igual
    u_r = random.random()
    x = u_r
    probabilidad_aceptar = f_x(x) / t(x)
    u_r = random.random()
    if u_r < probabilidad_aceptar:
        generados.append(x)

# %%
plt.scatter(range(len(generados)), generados, c ="blue")

# %%
plt.hist(generados)
# Out:
# (array([114.,  94.,  71.,  74.,  45.,  49.,  31.,  27.,  21.,  15.]),
#  array([3.45211767e-04, 9.37152985e-02, 1.87085385e-01, 2.80455472e-01,
#         3.73825559e-01, 4.67195645e-01, 5.60565732e-01, 6.53935819e-01,
#         7.47305905e-01, 8.40675992e-01, 9.34046079e-01]),
#  <BarContainer object of 10 artists>)
